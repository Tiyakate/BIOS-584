# %%
Tiyamika Williams

# %%
cat_ls =['cat1', 'cat1','cat1']
cat_ls.append('cat2')
print(cat_ls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 cat_ls =['cat1', 'cat1','cat1']
#       2 cat_ls.append('cat2')
# ----> 3 print(cat_ls)
#
# TypeError: 'NoneType' object is not callable

# %%
cat_ls.clear()
print (cat_ls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 cat_ls.clear()
# ----> 2 print (cat_ls)
#
# TypeError: 'NoneType' object is not callable

# %%
cat_ls.copy()
print(cat_ls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 cat_ls.copy()
# ----> 2 print(cat_ls)
#
# TypeError: 'NoneType' object is not callable

# %%
q4=['cat1', 'cat1','cat2'].index ('cat2')
print(q4)
# Out:
# 2

# %%
q5=['cat1', 'cat1','cat2'].insert (1,'cat2')
print=q5
