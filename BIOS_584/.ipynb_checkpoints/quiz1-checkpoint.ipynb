# %%
Tiyamika Williams

# %%
cat_ls =['cat1', 'cat1','cat1']
cat_ls.append('cat2')
print(cat_ls)
# Out:
# ['cat1', 'cat1', 'cat1', 'cat2']

# %%
cat_ls.clear()
print (cat_ls)
# Out:
# []

# %%
cat_ls.copy()
print(cat_ls)
# Out:
# []

# %%
cat2_ls= ['cat1', 'cat1', 'cat2']
cat2_ls.count('cat1')
# Out:
# 2

# %%
cat2_ls.index ('cat2')
# Out:
# 2

# %%
cat2_ls.insert (1,'cat2')
print(cat2_ls)
# Out:
# ['cat1', 'cat2', 'cat2', 'cat1', 'cat2']

# %%
cat2_ls.pop(2)
# Out:
# 'cat2'

# %%
cat2_ls.remove('cat2')
print(cat2_ls)
# Out:
# ['cat1', 'cat1']

# %%
cat2_ls.reverse()
print(cat2_ls)
# Out:
# ['cat1', 'cat1']
